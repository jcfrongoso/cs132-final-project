# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_excel('./Dataset/2M4ACP09.xlsx', skiprows=3)
df.head()
# Out:
#                         Unnamed: 0                                 Unnamed: 1  \
# 0  ..National Capital Region (NCR)                              0 - ALL ITEMS
# 1                              NaN      01 - FOOD AND NON-ALCOHOLIC BEVERAGES
# 2                              NaN                                01.1 - FOOD
# 3                              NaN  01.1.1 - Cereals and cereal products (ND)
# 4                              NaN                    01.1.1.1 - Cereals (ND)
#
#         Jan        Feb        Mar        Apr        May        Jun        Jul  \
# 0      96.9         98         99       99.3       99.2       99.6      100.4
# 1      97.4       97.7         98         98       97.8       98.7      100.2
# 2      97.6       97.8         98       97.9       97.6       98.5      100.2
# 3      97.2       97.6       98.3       98.4       98.4       98.7       99.6
# 4  96.68672  97.058674  97.964018  98.044541  98.014789  98.335869  99.437352
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df = df.rename(columns={'Unnamed: 1': 'Items'})

# %%
df.dropna(axis=0, how='all', inplace=True)

# %%
df.shape
# Out:
# (354, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 354 entries, 0 to 353
# Data columns (total 85 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Items   354 non-null    object
#  1   Jan     354 non-null    object
#  2   Feb     354 non-null    object
#  3   Mar     354 non-null    object
#  4   Apr     354 non-null    object
#  5   May     354 non-null    object
#  6   Jun     354 non-null    object
#  7   Jul     354 non-null    object
#  8   Aug     354 non-null    object
#  9   Sep     354 non-null    object
#  10  Oct     354 non-null    object
#  11  Nov     354 non-null    object
#  12  Dec     354 non-null    object
#  13  Jan.1   354 non-null    object
#  14  Feb.1   354 non-null    object
#  15  Mar.1   354 non-null    object
#  16  Apr.1   354 non-null    object
#  17  May.1   354 non-null    object
#  18  Jun.1   354 non-null    object
#  19  Jul.1   354 non-null    object
#  20  Aug.1   354 non-null    object
# ...

# %%
df.describe()
# Out:
#                 Items  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  ...  \
# count             354  354  354  354  354  354  354  354  354  354  ...
# unique            354  221  209  207  205  207  206  206  208  208  ...
# top     0 - ALL ITEMS  100  100  100  100  100  100  100  100  100  ...
# freq                1   30   32   34   37   40   34   33   33   33  ...
#
#         Mar.6  Apr.6  May.6  Jun.6  Jul.6  Aug.6  Sep.6  Oct.6  Nov.6 Dec.6
# count     354    354    354    354    354    354    354    354    354   354
# unique    286    290    285    289    290    292    295    287    292   289
# top        ..     ..     ..     ..     ..     ..     ..     ..     ..    ..
# freq       20     20     20     20     20     20     20     20     20    20
#
# [4 rows x 85 columns]

# %% [markdown]
# One more thing to do before analysis is to rename the columns such that the month and year is indicated.

# %% [markdown]
# # Problem Definition

# %% [markdown]
# Given the CPI of Education, as a whole, how does its changes correlate to the daily expenses of food, household stuff, etc. in the nearing future?

# %% [markdown]
# Multivariable comparison lang naman given yung CPI values.
