# %%
import pandas as pd
import numpy as np
import os

# %%
dir = './Dataset/Approved Investments.csv'

ai_df = pd.read_csv(dir, skiprows=2)
ai_df.head()
# Out:
#                   Country  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1  \
# 0               Australia    186.9    133.6    164.3     85.3    43.61
# 1  British Virgin Islands    110.1      0.0    249.2      0.0     0.00
# 2                  Canada    205.0      0.0      8.6     29.2    14.41
# 3          Cayman Islands    428.5      0.0      0.0      0.0  1136.77
# 4            China (PROC)   5042.0     69.7   9582.6    902.0   399.05
#
#    2021 Q2  2021 Q3  2021 Q4  2022 Q1  ...  2022 Q3  2022 Q4  2023 Q1  \
# 0   284.50   161.80   174.41   220.45  ...   120.31    96.25   449.85
# 1     0.00   698.32     0.00   220.38  ...   524.12  2138.45    15.81
# 2     0.04     0.00   357.75     5.31  ...    19.69    14.02    18.24
# 3     0.00     0.00   251.80     0.00  ...     2.39    21.19     0.00
# 4   678.24   349.65   717.08   182.53  ...   579.57   253.77   291.78
#
#     2023 Q2  2023 Q3  2023 Q4  2024 Q1  2024 Q2  2024 Q3  2024 Q4
# ...

# %%
ai_df.shape
# Out:
# (20, 21)

# %%
ai_df
# Out:
#                    Country  2020 Q1  2020 Q2  2020 Q3  2020 Q4   2021 Q1  \
# 0                Australia    186.9    133.6    164.3     85.3     43.61
# 1   British Virgin Islands    110.1      0.0    249.2      0.0      0.00
# 2                   Canada    205.0      0.0      8.6     29.2     14.41
# 3           Cayman Islands    428.5      0.0      0.0      0.0   1136.77
# 4             China (PROC)   5042.0     69.7   9582.6    902.0    399.05
# 5                  Denmark      0.0      0.0      0.0      0.0      0.00
# 6                   France   1513.8      3.9      3.7    148.4     56.84
# 7                  Germany    118.7      0.0    617.2     27.5    407.40
# 8                 Hongkong      1.0     69.4     19.8    210.3    146.81
# 9                    India    324.9      3.9      0.0    690.6     34.05
# 10                   Japan   1274.3    514.4   3306.7   4280.7  10716.55
# 11             South Korea   2131.3    150.7      5.4   1871.0    798.29
# ...

# %%
ai_df = ai_df.melt('Country')
ai_df.columns = ['Country', 'Quarter', 'Investment']

# %%
ai_df.head()
# Out:
#                   Country  Quarter  Investment
# 0               Australia  2020 Q1       186.9
# 1  British Virgin Islands  2020 Q1       110.1
# 2                  Canada  2020 Q1       205.0
# 3          Cayman Islands  2020 Q1       428.5
# 4            China (PROC)  2020 Q1      5042.0

# %%
ai_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     400 non-null    object
#  1   Quarter     400 non-null    object
#  2   Investment  400 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 9.5+ KB

# %%
ai_df.describe()
# Out:
#           Investment
# count     400.000000
# mean     4764.332100
# std     28827.056239
# min         0.000000
# 25%         3.975000
# 50%       187.540000
# 75%      1138.270000
# max    392401.040000

# %%
def get_second_value(val):
    return val.split()[1]

ai_df['Quarter'] = ai_df['Quarter'].apply(get_second_value)

# %%
from matplotlib import pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact

def plot(country):
    filtered = ai_df[ai_df['Country'] == country]
    plt.plot(filtered['Quarter'], filtered['Investment'])
    plt.show()

countries = list(ai_df['Country'].unique())

x = widgets.Dropdown(options=countries)

interact(plot, country=x)
# Out:
# interactive(children=(Dropdown(description='country', options=('Australia', 'British Virgin Islands', 'Canada'…
# <function __main__.plot(country)>
