# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
print(os.listdir('./Dataset/'))
# Out:
# ['Aquaculture Value and Volume of Production - Merged CSV.csv', 'Aquaculture Value of Production by Species, Geolocation, Year and Quarter.csv', 'Aquaculture Volume of Production by Species, Geolocation, Year and Quarter.csv']

# %%
aquaculture_value = './Dataset/Aquaculture Value of Production by Species, Geolocation, Year and Quarter.csv'
aquaculture_volume = './Dataset/Aquaculture Volume of Production by Species, Geolocation, Year and Quarter.csv'

value_df = pd.read_csv(aquaculture_value, skiprows=2)
volume_df = pd.read_csv(aquaculture_volume, skiprows=2)

# %% [markdown]
# ## Value Dataframe Check

# %%
value_df.head()
# Out:
#        Species                               Geolocation 2020 Quarter 1  \
# 0  All Species           ..National Capital Region (NCR)       10190.23
# 1  All Species  ..Cordillera Administrative Region (CAR)       72535.13
# 2  All Species                ..Region I (Ilocos Region)     3062615.94
# 3  All Species              ..Region II (Cagayan Valley)      213501.70
# 4  All Species              ..Region III (Central Luzon)     9137119.99
#
#   2020 Quarter 2 2020 Quarter 3 2020 Quarter 4 2021 Quarter 1 2021 Quarter 2  \
# 0        7107.16       31109.24         690.61        5612.63       13116.33
# 1       71605.89       63179.79       83469.73       86797.81       86806.70
# 2     2935063.73     2277160.92     8225306.14     3318099.54     3627335.60
# 3      673595.33      465509.14      512671.28      224298.32      709289.25
# 4    14120277.00     4624628.78    10242874.70    10120596.51    14887526.14
#
#   2021 Quarter 3 2021 Quarter 4  ... 2022 Quarter 3 2022 Quarter 4  \
# 0       25643.24        3145.26  ...       25025.90       25705.39
# 1       73271.87       96993.03  ...       89126.50       95616.17
# 2     3055883.81     9651054.24  ...     4008946.21     8536942.72
# 3      449045.07      569854.45  ...      706846.76      573447.57
# 4     5105722.25    11782029.78  ...     4413429.04    11983872.94
#
#   2023 Quarter 1 2023 Quarter 2 2023 Quarter 3 2023 Quarter 4 2024 Quarter 1  \
# 0       45180.57       82414.05       53537.64       20412.98       17456.54
# 1       82654.88      110723.10       74849.87       85026.09       94935.26
# 2     3815418.54     5166955.22     4418993.45     9226910.19     3557411.46
# 3      368371.15     1013956.41      754175.87      628779.78      435131.55
# 4    13183639.32    13028333.57     6870963.18    14298248.00    14127397.93
#
#   2024 Quarter 2 2024 Quarter 3 2024 Quarter 4
# 0       55008.25       28303.01        6722.96
# 1       81611.16       93064.73      111993.23
# 2     4276436.66     3798706.51     9894699.27
# 3      860602.55      808622.41      460937.65
# 4     9265737.61     5510636.98    13398491.78
#
# [5 rows x 22 columns]

# %%
value_df.describe()
# Out:
#             Species                      Geolocation 2020 Quarter 1  \
# count           340                              340            340
# unique           20                               17            240
# top     All Species  ..National Capital Region (NCR)             ..
# freq             17                               20             99
#
#        2020 Quarter 2 2020 Quarter 3 2020 Quarter 4 2021 Quarter 1  \
# count             340            340            340            340
# unique            243            242            246            235
# top                ..             ..             ..             ..
# freq               96             97             94            100
#
#        2021 Quarter 2 2021 Quarter 3 2021 Quarter 4  ... 2022 Quarter 3  \
# count             340            340            340  ...            340
# unique            238            237            248  ...            248
# top                ..             ..             ..  ...             ..
# freq               98            102             91  ...             92
#
#        2022 Quarter 4 2023 Quarter 1 2023 Quarter 2 2023 Quarter 3  \
# count             340            340            340            340
# unique            248            255            252            240
# top                ..             ..             ..             ..
# freq               93             86             89            101
#
#        2023 Quarter 4 2024 Quarter 1 2024 Quarter 2 2024 Quarter 3  \
# count             340            340            340            340
# unique            240            239            252            241
# top                ..             ..             ..             ..
# freq              101            102             89            100
#
#        2024 Quarter 4
# count             340
# unique            249
# top                ..
# freq               91
#
# [4 rows x 22 columns]

# %%
value_df.shape
# Out:
# (340, 22)

# %%
value_df.columns
# Out:
# Index(['Species', 'Geolocation', '2020 Quarter 1', '2020 Quarter 2',
#        '2020 Quarter 3', '2020 Quarter 4', '2021 Quarter 1', '2021 Quarter 2',
#        '2021 Quarter 3', '2021 Quarter 4', '2022 Quarter 1', '2022 Quarter 2',
#        '2022 Quarter 3', '2022 Quarter 4', '2023 Quarter 1', '2023 Quarter 2',
#        '2023 Quarter 3', '2023 Quarter 4', '2024 Quarter 1', '2024 Quarter 2',
#        '2024 Quarter 3', '2024 Quarter 4'],
#       dtype='object')

# %%
value_df['Species'].value_counts()
# Out:
# Species
# All Species           17
# ..Milkfish            17
# ..Mussel              17
# ..Oyster              17
# ..Others              17
# ..Freshwater Prawn    17
# ..Mudfish             17
# ..Gourami             17
# ..Catfish             17
# ..Carp                17
# ..Spiny Lobster       17
# ..P. Vannamei         17
# ..Siganid             17
# ..Grouper             17
# ..White Shrimp        17
# ..Endeavor Prawn      17
# ..Mudcrab             17
# ..Tiger Prawn         17
# ..Tilapia             17
# ..Seaweed             17
# Name: count, dtype: int64

# %%
value_df = value_df[value_df['Species'] != 'All Species']

# %%
value_df['Species'] = value_df['Species'].str.slice(start=2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18488\1720751696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   value_df['Species'] = value_df['Species'].str.slice(start=2)

# %%
value_df.head()
# Out:
#      Species                               Geolocation 2020 Quarter 1  \
# 17  Milkfish           ..National Capital Region (NCR)        2853.50
# 18  Milkfish  ..Cordillera Administrative Region (CAR)             ..
# 19  Milkfish                ..Region I (Ilocos Region)     2721045.87
# 20  Milkfish              ..Region II (Cagayan Valley)        1623.57
# 21  Milkfish              ..Region III (Central Luzon)     1159738.77
#
#    2020 Quarter 2 2020 Quarter 3 2020 Quarter 4 2021 Quarter 1 2021 Quarter 2  \
# 17        2980.67       26813.66         269.45        2303.66       10100.35
# 18             ..             ..             ..             ..             ..
# 19     1772567.51     2058099.74     7633914.73     2999911.67     2716007.93
# 20       64234.71        2309.58         722.79        1668.03       77353.68
# 21     4338613.29      965799.21     2090098.03     1373695.56     4847022.38
#
#    2021 Quarter 3 2021 Quarter 4  ... 2022 Quarter 3 2022 Quarter 4  \
# 17        3215.96        1174.66  ...        8689.21        3562.05
# 18             ..             ..  ...             ..             ..
# 19     2828743.17     9076969.67  ...     3792090.20     8076617.42
# 20        2365.24         732.92  ...       13812.32         627.30
# 21     1066352.36     2652448.07  ...     1512014.56     2391593.08
#
#    2023 Quarter 1 2023 Quarter 2 2023 Quarter 3 2023 Quarter 4 2024 Quarter 1  \
# 17       20885.76       34328.31        5248.50        6024.01        7083.11
# 18             ..             ..             ..             ..             ..
# 19     3523480.49     3103180.63     4193562.16     8781399.31     3245786.40
# 20        3804.14       85552.60       18665.99         781.98        6060.67
# 21     1903219.57     1785182.98     1559673.60     2626684.66     1426591.07
#
#    2024 Quarter 2 2024 Quarter 3 2024 Quarter 4
# 17       30346.15        8567.34        4001.35
# 18             ..             ..             ..
# 19     2742036.67     3623346.05     9455618.22
# 20       50672.09       22620.79         727.37
# 21     1428380.65     1123880.83     2453522.17
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Volume Dataframe Check
